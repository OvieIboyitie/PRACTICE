# %%
import math
import matplotlib.pyplot as plt

def Euler_Cuachy_Method(x,x2,y,h,func):
    y_prime = func(x,y)
    #y_aux = y + h * func(x,y)
    #yN = y + 0.5 * h * (y_prime + (y_aux - x))
    x_list = []
    y_numerical = []
    yA = (x + 1) + 1 * math.exp(x)
    y_analtical = []
    #i = 1
    while x < (x2+h) :
        y_numerical.append(y)
        x_list.append(x)
        y_analtical.append(yA)
        x = x + h
        y_aux = y + h * y_prime
        yN = y + 0.5 * h * (y_prime + func(x,y_aux))
        y = yN
        yA = (x + 1) + 1 * math.exp(x) 
        
        y_prime = func(x,yN)
    return x_list, y_numerical, y_analtical

def func11(x,y):
    return (y-x)
def cosine(x,y):
    return(math.cos(x))

a = Euler_Method(0,0.5,2, 0.1, func11)    

x_values = a[0]
print(">>>>>>>>>>>>>>> x_values <<<<<<<<<<<<<<<< \n")
print(x_values)
y_num_values = a[1]
print(">>>>>>>>>>>>>>> y_num_values <<<<<<<<<<<<<<<< \n")
print(y_num_values)
y_anal_values = a[2]
print(">>>>>>>>>>>>>>> y_anal_values <<<<<<<<<<<<<<<< \n")
print(y_anal_values)
error = [analy - numeric for analy, numeric in zip(y_anal_values, y_num_values)]
print(">>>>>>>>>>>>>>> error <<<<<<<<<<<<<<<< \n")
print(error)
plt.plot(x_values, y_num_values, "--b", label = "Numerical")
plt.plot(x_values, y_anal_values, "-r", label = "Analytical")
plt.legend(loc = "upper left")
#plt.plot(x_values, error)
plt.grid()
plt.show()
plt.legend(loc = "upper left")
plt.plot(x_values, error, "-r", label = "error")
plt.legend(loc = "upper left")
plt.grid()
plt.show()
# Out:
# >>>>>>>>>>>>>>> x_values <<<<<<<<<<<<<<<<
#
# [0, 0.1, 0.2, 0.30000000000000004, 0.4, 0.5]
# >>>>>>>>>>>>>>> y_num_values <<<<<<<<<<<<<<<<
#
# [2, 2.205, 2.421025, 2.6492326250000002, 2.8909020506250003, 3.147446765940625]
# >>>>>>>>>>>>>>> y_anal_values <<<<<<<<<<<<<<<<
#
# [2.0, 2.205170918075648, 2.42140275816017, 2.6498588075760034, 2.8918246976412703, 3.148721270700128]
# >>>>>>>>>>>>>>> error <<<<<<<<<<<<<<<<
#
# [0.0, 0.0001709180756477302, 0.0003777581601696056, 0.0006261825760032202, 0.000922647016269984, 0.0012745047595030812]
# No handles with labels found to put in legend.

# %%
x_values = a[0]
#print(">>>>>>>>>>>>>>> x_values <<<<<<<<<<<<<<<< \n")
#print(x_values)
y_num_values = a[1]
#print(">>>>>>>>>>>>>>> y_num_values <<<<<<<<<<<<<<<< \n")
#print(y_num_values)
y_anal_values = a[2]
#print(">>>>>>>>>>>>>>> y_anal_values <<<<<<<<<<<<<<<< \n")
#print(y_anal_values)
error = [analy - numeric for analy, numeric in zip(y_anal_values, y_num_values)]
#print(">>>>>>>>>>>>>>> error <<<<<<<<<<<<<<<< \n")
#print(error)
plt.plot(x_values, y_num_values, "--b", label = "Numerical")
plt.plot(x_values, y_anal_values, "-r", label = "Analytical")
plt.legend(loc = "upper left")
#plt.plot(x_values, error)
plt.grid()
plt.show()
plt.legend(loc = "upper left")
plt.plot(x_values, error, "-r", label = "error")
plt.legend(loc = "upper left")
plt.grid()
plt.show()



x_values = a[0]

y_num_values = a[1]

y_anal_values = a[2]
error = [analy - numeric for analy, numeric in zip(y_anal_values, y_num_values)]

plt.plot(x_values, y_num_values, "--b", label = "Numerical")
plt.plot(x_values, y_anal_values, "-r", label = "Analytical")
plt.legend(loc = "upper left")
plt.grid()
plt.show()


plt.plot(x_values, error, "-r", label = "error")
plt.legend(loc = "upper left")
plt.grid()
plt.show()

# %%
import math
import matplotlib.pyplot as plt

def Euler_Method(x,x2,y,h,func):
    y_prime = func(x,y)
    #y_aux = y + h * func(x,y)
    #yN = y + 0.5 * h * (y_prime + (y_aux - x))
    x_list = []
    y_numerical = []
    ya = 3*x + math.exp(1-x)
    y_analtical = []
    #i = 1
    while x < (x2+h) :
        y_numerical.append(y)
        x_list.append(x)
        y_analtical.append(ya)
        x = x + h
        y_aux = y + h * y_prime
        yN = y + 0.5 * h * (y_prime + (func(x,y_aux)))
        y = yN
        ya = 3*x + math.exp(1-x)
        
        y_prime = func(x,yN)
    return x_list, y_numerical, y_analtical

def func11(x,y):
    return (3*(1+x)-y)

a = Euler_Method(1,2,4, 0.2, func11)   

x_values = a[0]

y_num_values = a[1]

y_anal_values = a[2]
error = [analy - numeric for analy, numeric in zip(y_anal_values, y_num_values)]

plt.plot(x_values, y_num_values, "--b", label = "Numerical")
plt.plot(x_values, y_anal_values, "-r", label = "Analytical")
plt.legend(loc = "upper left")
plt.grid()
plt.show()


plt.plot(x_values, error, "-r", label = "error")
plt.legend(loc = "upper left")
plt.grid()
plt.show()

# %%
 import math
import matplotlib.pyplot as plt

def Euler_Method(x,x2,y,h,func):
    y_prime = func(x,y)
    #y_aux = y + h * func(x,y)
    #yN = y + 0.5 * h * (y_prime + (y_aux - x))
    x_list = []
    y_numerical = []
    yA = math.sin(x) 
    y_analtical = []
    #i = 1
    while x < (x2+h) :
        y_numerical.append(y)
        x_list.append(x)
        y_analtical.append(yA)
        x = x + h
        y_aux = y + h * y_prime
        yN = y + 0.5 * h * (y_prime + func(x,y_aux))
        y = yN
        yA = math.sin(x) 
        
        y_prime = func(x,yN)
    return x_list, y_numerical, y_analtical

def cosine(x,y):
    return math.cos(x)

a = Euler_Method(0,2*math.pi,0, 0.2, cosine)
x_values = a[0]

y_num_values = a[1]

y_anal_values = a[2]
error = [analy - numeric for analy, numeric in zip(y_anal_values, y_num_values)]

plt.plot(x_values, y_num_values, "--b", label = "Numerical")
plt.plot(x_values, y_anal_values, "-r", label = "Analytical")
plt.legend(loc = "upper left")
plt.grid()
plt.show()


plt.plot(x_values, error, "-r", label = "error")
plt.legend(loc = "upper left")
plt.grid()
plt.show()
