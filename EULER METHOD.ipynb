# %%
import math
import matplotlib.pyplot as plt
def Euler_Method(x,x2,y,h,func):
    yN = y + h * func(x,y)
    xlist = []
    ynumerical = []
    ya = 3*x + math.exp(1-x) 
    yana = []
    while x <= x2 :
        ynumerical.append(y)
        y_prime = func(x,y)
        yN = y + h * y_prime
        ya = 3*x + math.exp(1-x)
        yana.append(ya)
        xlist.append(x)
        #ynumerical.append(yN)
        x = x + h
        y = yN
    return xlist, ynumerical, yana
def func11(x,y):
    return (3*(1+x)-y)
a = Euler_Method(1,2,4, 0.2, func11)
x_values = a[0]
print(x_values)
y_num_values = a[1]
print(y_num_values)
y_anal_values = a[2]
print(y_anal_values)
error = [analy - numeric for analy, numeric in zip(y_anal_values, y_num_values)]
print(error)
plt.plot(x_values, y_num_values)
plt.plot(x_values, y_anal_values)
#plt.plot(x_values, error)
plt.grid()
plt.show()
plt.legend()
plt.plot(x_values, error)
plt.grid()
plt.show()
# Out:
# [1, 1.2, 1.4, 1.5999999999999999, 1.7999999999999998, 1.9999999999999998]
# [4, 4.4, 4.840000000000001, 5.312, 5.8096, 6.327679999999999]
# [4.0, 4.418730753077981, 4.870320046035639, 5.348811636094027, 5.8493289641172215, 6.367879441171442]
# [0.0, 0.018730753077981, 0.030320046035638093, 0.03681163609402649, 0.03972896411722182, 0.04019944117144281]
# No handles with labels found to put in legend.

# %%
import math
import matplotlib.pyplot as plt

def Euler_Method(x,x2,y,h,func):
    yN = y + h * func(x,y)
    xlist = []
    ynumerical = []
    ya = 2*x +(5/4) * math.exp(2-x) 
    yana = []
    i = 1
    while x < (x2+h) :
        ynumerical.append(y)
        y_prime = func(x,y)
        yN = y + h * y_prime
        ya = 2*x +  math.exp(2-x) 
        yana.append(ya)
        xlist.append(x)
        x = x + h
        y = yN
    return xlist, ynumerical, yana
def func41(x,y):
    return (2*(1+x)-y)

a = Euler_Method(2,3,5, 0.02, func41)    
x_values = a[0]
y_num_values = a[1]
y_anal_values = a[2]
error = [analy - numeric for analy, numeric in zip(y_anal_values, y_num_values)]
plt.plot(x_values, y_num_values)
plt.plot(x_values, y_anal_values)
#plt.plot(x_values, error)
plt.grid()
plt.show()
plt.plot(x_values, error)
plt.grid()
plt.show()

# %% [markdown]
# # SOLVING SINX USING EULER METHOD

# %%
import math
import matplotlib.pyplot as plt

def Euler_Method(x,x2,y,h,func):
    yN = y + h * func(x,y)
    xlist = []
    ynumerical = []
    ya = -1 * math.cos(x) + 1
    yana = []
    i = 1
    while x < (x2+h) :
        ynumerical.append(y)
        y_prime = func(x,y)
        yN = y + h * y_prime
        ya = -1 * math.cos(x) + 1
        yana.append(ya)
        xlist.append(x)
        x = x + h
        y = yN
    return xlist, ynumerical, yana
def sine(x,y):
    return math.sin(x)

a = Euler_Method(0,math.pi,0, 0.2, sine)    
x_values = a[0]
#print(">>>>>>>>>>>>>>> x_values <<<<<<<<<<<<<<<< \n")
#print(x_values)
y_num_values = a[1]
#print(">>>>>>>>>>>>>>> y_num_values <<<<<<<<<<<<<<<< \n")
#print(y_num_values)
y_anal_values = a[2]
#print(">>>>>>>>>>>>>>> y_anal_values <<<<<<<<<<<<<<<< \n")
#print(y_anal_values)
error = [analy - numeric for analy, numeric in zip(y_anal_values, y_num_values)]
#print(">>>>>>>>>>>>>>> error <<<<<<<<<<<<<<<< \n")
#print(error)
plt.plot(x_values, y_num_values, "--b", label = "Numerical")
plt.plot(x_values, y_anal_values, "-r", label = "Analytical")
plt.legend(loc = "upper left")
#plt.plot(x_values, error)
plt.grid()
plt.show()
plt.legend(loc = "upper left")
plt.plot(x_values, error, "-r", label = "error")
plt.legend(loc = "upper left")
plt.grid()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # SOLVING COS X USING EULERS METHOD

# %%
import math
import matplotlib.pyplot as plt

def Euler_Method(x,x2,y,h,func):
    yN = y + h * func(x,y)
    x_list = []
    y_numerical = []
    yA = math.sin(x) 
    y_analtical = []
    i = 1
    while x < (x2+h) :
        y_numerical.append(y)
        y_prime = func(x,y)
        yN = y + h * y_prime
        yA = math.sin(x)
        y_analtical.append(yA)
        x_list.append(x)
        x = x + h
        y = yN
    return x_list, y_numerical, y_analtical
def cosine(x,y):
    return math.cos(x)

a = Euler_Method(0,math.pi,0, 0.2, cosine)    
x_values = a[0]
#print(">>>>>>>>>>>>>>> x_values <<<<<<<<<<<<<<<< \n")
#print(x_values)
y_num_values = a[1]
#print(">>>>>>>>>>>>>>> y_num_values <<<<<<<<<<<<<<<< \n")
#print(y_num_values)
y_anal_values = a[2]
#print(">>>>>>>>>>>>>>> y_anal_values <<<<<<<<<<<<<<<< \n")
#print(y_anal_values)
error = [analy - numeric for analy, numeric in zip(y_anal_values, y_num_values)]
#print(">>>>>>>>>>>>>>> error <<<<<<<<<<<<<<<< \n")
#print(error)
plt.plot(x_values, y_num_values, "--b", label = "Numerical")
plt.plot(x_values, y_anal_values, "-r", label = "Analytical")
plt.legend(loc = "upper left")
#plt.plot(x_values, error)
plt.grid()
plt.show()
plt.legend(loc = "upper left")
plt.plot(x_values, error, "-r", label = "error")
plt.legend(loc = "upper left")
plt.grid()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
import math
import matplotlib.pyplot as plt

def Euler_Method(x,x2,y,h,func):
    yN = y + h * func(x,y)
    x_list = []
    y_numerical = []
    yA = (x - 1) + 3 * math.exp(x)
    y_analtical = []
    i = 1
    while x < (x2+h) :
        y_numerical.append(y)
        y_prime = func(x,y)
        yN = y + h * y_prime
        yA = (x - 1) + 3 * math.exp(x)
        y_analtical.append(yA)
        x_list.append(x)
        x = x + h
        y = yN
    return x_list, y_numerical, y_analtical
def cosine(x,y):
    return (y-x)

a = Euler_Method(0,0.5,2, 0.1, cosine)    
x_values = a[0]
#print(">>>>>>>>>>>>>>> x_values <<<<<<<<<<<<<<<< \n")
#print(x_values)
y_num_values = a[1]
#print(">>>>>>>>>>>>>>> y_num_values <<<<<<<<<<<<<<<< \n")
#print(y_num_values)
y_anal_values = a[2]
#print(">>>>>>>>>>>>>>> y_anal_values <<<<<<<<<<<<<<<< \n")
#print(y_anal_values)
error = [analy - numeric for analy, numeric in zip(y_anal_values, y_num_values)]
#print(">>>>>>>>>>>>>>> error <<<<<<<<<<<<<<<< \n")
#print(error)
plt.plot(x_values, y_num_values, "--b", label = "Numerical")
plt.plot(x_values, y_anal_values, "-r", label = "Analytical")
plt.legend(loc = "upper left")
#plt.plot(x_values, error)
plt.grid()
plt.show()
plt.legend(loc = "upper left")
plt.plot(x_values, error, "-r", label = "error")
plt.legend(loc = "upper left")
plt.grid()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
import math
import matplotlib.pyplot as plt
import numpy as np
def Euler_Method(x,x2,y,h,func):
    yN = y + h * func(x,y)
    x_list = []
    y_numerical = []
    yA = 70/9 *  math.exp(-0.3 * x) - 43/9 * math.exp(-1.2 * x)
    y_analtical = []
    i = 1
    while x < (x2+h) :
        y_numerical.append(y)
        y_prime = func(x,y)
        yN = y + h * y_prime
        yA = 70/9 *  math.exp(-0.3 * x) - 43/9 * math.exp(-1.2 * x)
        y_analtical.append(yA)
        x_list.append(x)
        x = x + h
        y = yN
    return x_list, y_numerical, y_analtical
def func51(x,y):
    return (-1.2 * y + 7 * math.exp(-0.3 * x))

a = Euler_Method(0,2.5,3, 0.1, func51)    
x_values = a[0]
print(">>>>>>>>>>>>>>> x_values <<<<<<<<<<<<<<<< \n")
print(x_values)
y_num_values = a[1]
print(y_num_values)
y_anal_values = a[2]
error = [analy - numeric for analy, numeric in zip(y_anal_values, y_num_values)]
#print(">>>>>>>>>>>>>>> error <<<<<<<<<<<<<<<< \n")
#print(error)
plt.plot(x_values, y_num_values, "--b", label = "Numerical")
plt.plot(x_values, y_anal_values, "-r", label = "Analytical")
plt.legend(loc = "upper left")
#plt.plot(x_values, error)
plt.grid()
plt.show()
plt.legend(loc = "upper left")
plt.plot(x_values, error, "-r", label = "error")
plt.legend(loc = "upper left")
plt.grid()
plt.show()
# Out:
# >>>>>>>>>>>>>>> x_values <<<<<<<<<<<<<<<<
#
# [0, 0.1, 0.2, 0.30000000000000004, 0.4, 0.5, 0.6, 0.7, 0.7999999999999999, 0.8999999999999999, 0.9999999999999999, 1.0999999999999999, 1.2, 1.3, 1.4000000000000001, 1.5000000000000002, 1.6000000000000003, 1.7000000000000004, 1.8000000000000005, 1.9000000000000006, 2.0000000000000004, 2.1000000000000005, 2.2000000000000006, 2.3000000000000007, 2.400000000000001, 2.500000000000001]
# [3, 3.34, 3.6185118734839556, 3.8435256221748553, 4.022054377203732, 4.1602521576412945, 4.2635174822218795, 4.336584532343144, 4.383603360641097, 4.4082104601107535, 4.413590850933261, 4.402532703298472, 4.377475392305003, 4.340551773478125, 4.293625372809465, 4.238323101942869, 4.176064035844965, 4.108084725807868, 4.03546146387951, 3.959129864875761, 3.8799020881803457, 3.798481982864523, 3.7154784056256083, 3.6314169310947246, 3.5467501477095964, 3.461866709156425]
# No handles with labels found to put in legend.
# (0, 3)
# (0.1, 3.34)
# (0.2, 3.6185118734839556)
# (0.30000000000000004, 3.8435256221748553)
# (0.4, 4.022054377203732)
# (0.5, 4.1602521576412945)
# (0.6, 4.2635174822218795)
# (0.7, 4.336584532343144)
# (0.7999999999999999, 4.383603360641097)
# (0.8999999999999999, 4.4082104601107535)
# (0.9999999999999999, 4.413590850933261)
# (1.0999999999999999, 4.402532703298472)
# (1.2, 4.377475392305003)
# (1.3, 4.340551773478125)
# (1.4000000000000001, 4.293625372809465)
# (1.5000000000000002, 4.238323101942869)
# (1.6000000000000003, 4.176064035844965)
# (1.7000000000000004, 4.108084725807868)
# (1.8000000000000005, 4.03546146387951)
# (1.9000000000000006, 3.959129864875761)
# (2.0000000000000004, 3.8799020881803457)
# (2.1000000000000005, 3.798481982864523)
# (2.2000000000000006, 3.7154784056256083)
# (2.3000000000000007, 3.6314169310947246)
# (2.400000000000001, 3.5467501477095964)
# (2.500000000000001, 3.461866709156425)

# %%
y_analtical.append(yA)
